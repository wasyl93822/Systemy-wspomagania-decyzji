# %% [markdown]
# <a href="https://colab.research.google.com/github/wasyl93822/Systemy-wspomagania-decyzji/blob/main/other_collections_3Tab%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data set generation
import numpy as np
import matplotlib.pyplot as plt
import random

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam, Adadelta, Nadam
from sklearn.model_selection import train_test_split

def generate_dataset():
    X = []
    y = []
    for i in range(5):
        t = np.linspace(0, 2 * np.pi, 1000) + i * np.pi / 5
        x = np.sin(t) * t
        y_ = np.cos(t) * t
        X_class = np.column_stack((x, y_))
        if i == 0:
            X = X_class
            y = np.array([i] * 1000)
        else:
            X = np.concatenate((X, X_class), axis=0)
            y = np.concatenate((y, np.array([i] * 1000)), axis=0)
    return X, y

# %%
def plot_dataset(X, y):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    for i in range(5):
        X_class = X[y == i]
        ax.scatter(X_class[:, 0], X_class[:, 1], label='Class {}'.format(i))
    ax.legend()
    plt.show()

# %%
(x, y) = generate_dataset()
plot_dataset(x, y)

# %%
class Classifier:
    def __init__(self, num_layers, neurons_per_layer, activation):
        self.num_layers = num_layers
        self.neurons_per_layer = neurons_per_layer
        self.activation = activation

    def build_model(self, input_shape):
        model = Sequential()
        model.add(Dense(self.neurons_per_layer, activation=self.activation, input_shape=(input_shape,)))
        for i in range(self.num_layers - 1):
            model.add(Dense(self.neurons_per_layer, activation=self.activation))
        model.add(Dense(10, activation='softmax'))
        return model

# %%
def train(X, y, model, optimizer, epochs):
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(X, y, epochs=epochs, verbose=0)
    return history

# %%
# Plot the training results
def plot_history(history):
    plt.plot(history.history['accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.show()

# %%
def plot_classification_results(X, y, model):
    y_probs = model.predict(X)
    y_pred = np.argmax(y_probs, axis=1)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    for i in range(5):
        X_class = X[y == i]
        y_pred_class = y_pred[y == i]
        X_class_3d = np.column_stack((X_class, np.zeros(len(X_class)))) # add a third dimension filled with zeros
        ax.scatter(X_class_3d[:, 0], X_class_3d[:, 1], X_class_3d[:, 2], c=y_pred_class,
                   label='Class {}'.format(i))
    ax.legend()
    plt.show()

# %%
def experiment(num_layers=3, neurons_per_layer=32, activation='relu', epochs=100):
    X, y = generate_dataset()
    plot_dataset(X, y)

    # Inicjalizacja modelu
    classifier = Classifier(num_layers, neurons_per_layer, activation)
    model = classifier.build_model(input_shape=2)

    # Kompilacja modelu
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    # Trenowanie modelu
    history = train(X, y, model, optimizer, epochs)
    plot_history(history)

    # Wyświetlenie wyników klasyfikacji
    plot_classification_results(X, y, model)

# Wywołanie eksperymentu z różnymi architekturami
experiment(num_layers=2, neurons_per_layer=16, activation='relu', epochs=100)
experiment(num_layers=3, neurons_per_layer=32, activation='tanh', epochs=100)
experiment(num_layers=4, neurons_per_layer=64, activation='sigmoid', epochs=100)
experiment(num_layers=2, neurons_per_layer=32, activation='elu', epochs=100)
experiment(num_layers=3, neurons_per_layer=64, activation='relu', epochs=100)
# Out:
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
